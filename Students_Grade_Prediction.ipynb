# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('student_grades')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
df.shape
# Out:
# (571, 43)

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# filling the null values

# %%
df = df.apply(lambda x: x.fillna(x.value_counts().index[1]))

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# null values are filled

# %%
df=df.drop('Seat No.',axis=1)

# %%
df
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
df.head()
# Out:
#   PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0     B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1      A      D     D+         D     B-      C      D      A     D+      D
# 2      A      B      A        B-     B+      A     B-     B+     A-     A-
# 3      D     C+     D+         D      D     A-     D+     C-      D     C+
# 4     A-     A-     A-        B+      A      A     A-     B+      A     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 42 columns]

# %%
df.tail()
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
#      ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 566  ...     A-     A-      A      A      A     B+     B+      B      A  3.798
# 567  ...     B+     B+      A      A     A-      B     A-      C     A-  3.772
# 568  ...     A-      B      A     B+      A      C     B+     A-     A-  3.470
# 569  ...      D      B      B     C-      D      C      B     B-      C  2.193
# 570  ...     C+      C     B-      D      F     C-     B+      D     C-  1.753
#
# [5 rows x 42 columns]

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %% [markdown]
# # univariate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(df['PH-121'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PH-121', ylabel='Density'>

# %%
sns.distplot(df['PH-121'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PH-121', ylabel='Density'>

# %%
sns.distplot(df['CY-105'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CY-105', ylabel='Density'>

# %%
sns.distplot(df['HS-105/12'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HS-105/12', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'],
#       dtype='object')

# %%
sns.distplot(df['MT-111'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MT-111', ylabel='Density'>

# %%
sns.distplot(df['CS-105'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CS-105', ylabel='Density'>

# %%
sns.distplot(df['CS-106'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CS-106', ylabel='Density'>

# %%
sns.distplot(df['EL-102'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EL-102', ylabel='Density'>

# %%
sns.distplot(df['EE-119'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EE-119', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'],
#       dtype='object')

# %%
sns.distplot(df['ME-107'])
# Out:
# C:\Users\MAYANK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ME-107', ylabel='Density'>

# %% [markdown]
# # bivariate analysis

# %%
sns.regplot(x='PH-121',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='PH-121', ylabel='CGPA'>

# %%
sns.regplot(x='HS-205/20',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='HS-205/20', ylabel='CGPA'>

# %%
sns.regplot(x='MT-222',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='MT-222', ylabel='CGPA'>

# %%
sns.regplot(x='EE-222',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='EE-222', ylabel='CGPA'>

# %%
sns.regplot(x='CS-215',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='CS-215', ylabel='CGPA'>

# %%
sns.regplot(x='MT-331',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='MT-331', ylabel='CGPA'>

# %%
sns.scatterplot(x='CS-414',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='CS-414', ylabel='CGPA'>

# %%
sns.scatterplot(x='CS-412',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='CS-412', ylabel='CGPA'>

# %%
sns.scatterplot(x='CS-306',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='CS-306', ylabel='CGPA'>

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.781086    5.071804    2.901926    4.245184    3.889667    2.838879
# std      3.046895    2.785317    2.962487    3.196949    2.995332    2.696709
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    3.000000    0.000000    2.000000    2.000000    0.000000
# 50%      3.000000    5.000000    2.000000    4.000000    4.000000    2.000000
# 75%      6.000000    7.000000    4.500000    7.000000    6.000000    4.000000
# max     12.000000   11.000000   12.000000   12.000000   12.000000   10.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     4.129597    3.952715    3.893170    4.772329  ...    4.054291
# ...

# %%
df.shape
# Out:
# (571, 42)

# %%
df['PH-121'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HS-101'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CY-105'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['MT-111'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (571, 42)

# %%
from scipy.stats import zscore
import numpy as np

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 60,  60,  60,  91, 137, 143, 143, 281, 281, 281, 288, 288, 340,
#         340, 352, 352, 382, 387, 387, 410, 423, 424, 432, 446, 447, 447,
#         453, 453, 454, 454, 454, 509, 513, 516, 516, 521, 522, 522, 527,
#         543, 543, 550, 550, 557, 560, 563, 565, 570], dtype=int64),
#  array([ 2, 11, 19, 15,  2,  2, 41, 11, 15, 41, 11, 41, 24, 37, 24, 37, 37,
#         37, 40, 37, 37, 37, 40, 36, 36, 37, 36, 40, 36, 37, 38, 36, 40, 36,
#         40, 36, 36, 40, 40, 36, 40, 37, 40, 37, 37, 38, 41, 36],
#        dtype=int64))

# %%
df_new = df[(z<3).all(axis=1)]
df_new
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 564       2       9       0          6       4       4       6       2
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df_new.shape
# Out:
# (540, 42)

# %%
data_loss= (571-540)/571*100

# %%
data_loss
# Out:
# 5.42907180385289

# %%
df=pd.DataFrame(data=df_new)
df
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 564       2       9       0          6       4       4       6       2
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.shape
# Out:
# (540, 42)

# %% [markdown]
# # skewness detection and removal

# %%
df.skew()
# Out:
# PH-121       0.584635
# HS-101       0.077832
# CY-105       0.965558
# HS-105/12    0.344139
# MT-111       0.476466
# CS-105       0.977089
# CS-106       0.628873
# EL-102       0.528183
# EE-119       0.613229
# ME-107       0.122724
# CS-107       0.430051
# HS-205/20    0.799688
# MT-222       0.186062
# EE-222       0.738212
# MT-224       0.430523
# CS-210       0.666813
# CS-211       0.084368
# CS-203       0.279581
# CS-214       0.044554
# EE-217       0.735911
# CS-212       0.410844
# CS-215       0.147881
# MT-331       0.667868
# EF-303       0.343269
# HS-304       0.445308
# CS-301       0.410829
# CS-302       0.610383
# TC-383       0.369818
# MT-442       0.866750
# EL-332       0.442229
# CS-318       0.330336
# CS-306       0.420846
# CS-312       0.439786
# CS-317       0.161825
# CS-403       0.604980
# CS-421       0.093875
# CS-406       1.167539
# CS-414       0.886118
# CS-419       0.444529
# CS-423       0.482573
# CS-412       0.549455
# ...

# %% [markdown]
# +/- 1.96 is acceptable range

# %% [markdown]
# # correlation

# %%
df.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.349464  0.530881   0.484650  0.428232  0.587163
# HS-101     0.349464  1.000000  0.311719   0.479569  0.415888  0.373196
# CY-105     0.530881  0.311719  1.000000   0.492305  0.521829  0.569253
# HS-105/12  0.484650  0.479569  0.492305   1.000000  0.482282  0.469285
# MT-111     0.428232  0.415888  0.521829   0.482282  1.000000  0.355744
# CS-105     0.587163  0.373196  0.569253   0.469285  0.355744  1.000000
# CS-106     0.282566  0.326553  0.364121   0.483397  0.510068  0.294760
# EL-102     0.390483  0.328975  0.410522   0.334560  0.529029  0.315746
# EE-119     0.581311  0.306640  0.486546   0.377653  0.391927  0.499288
# ME-107     0.517274  0.326452  0.464476   0.293262  0.449323  0.430356
# CS-107     0.455886  0.495517  0.451609   0.523290  0.446492  0.498041
# HS-205/20  0.262442  0.147384  0.227850   0.153283  0.310900  0.137758
# ...

# %%
plt.figure(figsize=(50,45))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# every column is negavtively correalted to CGPA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540 entries, 0 to 569
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     540 non-null    int32
#  1   HS-101     540 non-null    int32
#  2   CY-105     540 non-null    int32
#  3   HS-105/12  540 non-null    int32
#  4   MT-111     540 non-null    int32
#  5   CS-105     540 non-null    int32
#  6   CS-106     540 non-null    int32
#  7   EL-102     540 non-null    int32
#  8   EE-119     540 non-null    int32
#  9   ME-107     540 non-null    int32
#  10  CS-107     540 non-null    int32
#  11  HS-205/20  540 non-null    int32
#  12  MT-222     540 non-null    int32
#  13  EE-222     540 non-null    int32
#  14  MT-224     540 non-null    int32
#  15  CS-210     540 non-null    int32
#  16  CS-211     540 non-null    int32
#  17  CS-203     540 non-null    int32
#  18  CS-214     540 non-null    int32
#  19  EE-217     540 non-null    int32
# ...

# %% [markdown]
# # check multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x=df.iloc[:,0:-1]
x
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 564       2       9       0          6       4       4       6       2
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 564    2.607
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# Name: CGPA, Length: 540, dtype: float64

# %%
x.shape
# Out:
# (540, 41)

# %%
y.shape
# Out:
# (540,)

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif['VIF FACTOR']=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif['features']=x.columns
    print(vif)

# %%
vif_cal()
# Out:
#     VIF FACTOR   features
# 0     7.038608     PH-121
# 1     7.556287     HS-101
# 2     4.837220     CY-105
# 3     6.329679  HS-105/12
# 4     7.171440     MT-111
# 5     4.926093     CS-105
# 6     6.286704     CS-106
# 7     4.991549     EL-102
# 8     6.792476     EE-119
# 9     7.401963     ME-107
# 10    6.001071     CS-107
# 11    4.288629  HS-205/20
# 12    7.026570     MT-222
# 13    5.571847     EE-222
# 14    8.424805     MT-224
# 15    8.224472     CS-210
# 16    8.791749     CS-211
# 17    7.761131     CS-203
# 18   10.401913     CS-214
# 19    6.162715     EE-217
# 20   10.704657     CS-212
# 21    9.875284     CS-215
# 22    4.781455     MT-331
# 23    8.460511     EF-303
# 24    9.185042     HS-304
# 25   10.093715     CS-301
# 26    8.471722     CS-302
# 27    8.103963     TC-383
# 28    5.061710     MT-442
# 29    9.287029     EL-332
# 30    8.724426     CS-318
# 31   10.104346     CS-306
# 32    9.170975     CS-312
# 33   12.471521     CS-317
# ...

# %%
#dropping cs317 and cs301
df=df.drop(['CS-317','CS-301'],axis=1)
df
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 564       2       9       0          6       4       4       6       2
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
x-df.iloc[:,:-1]
x.shape
# Out:
# (540, 41)

# %%
vif_cal()
# Out:
#     VIF FACTOR   features
# 0     7.038608     PH-121
# 1     7.556287     HS-101
# 2     4.837220     CY-105
# 3     6.329679  HS-105/12
# 4     7.171440     MT-111
# 5     4.926093     CS-105
# 6     6.286704     CS-106
# 7     4.991549     EL-102
# 8     6.792476     EE-119
# 9     7.401963     ME-107
# 10    6.001071     CS-107
# 11    4.288629  HS-205/20
# 12    7.026570     MT-222
# 13    5.571847     EE-222
# 14    8.424805     MT-224
# 15    8.224472     CS-210
# 16    8.791749     CS-211
# 17    7.761131     CS-203
# 18   10.401913     CS-214
# 19    6.162715     EE-217
# 20   10.704657     CS-212
# 21    9.875284     CS-215
# 22    4.781455     MT-331
# 23    8.460511     EF-303
# 24    9.185042     HS-304
# 25   10.093715     CS-301
# 26    8.471722     CS-302
# 27    8.103963     TC-383
# 28    5.061710     MT-442
# 29    9.287029     EL-332
# 30    8.724426     CS-318
# 31   10.104346     CS-306
# 32    9.170975     CS-312
# 33   12.471521     CS-317
# ...

# %% [markdown]
# # pca

# %%
from sklearn.decomposition import PCA

# %%
pc=PCA(n_components=10)
x=pc.fit_transform(x)
x
# Out:
# array([[ 17.39371142,  -1.36360518,  -7.71391418, ...,  -0.34668804,
#           1.56785058,   1.88830167],
#        [ 18.99569169,  -3.16818051,  -1.06660337, ...,  -0.17223687,
#          -3.72414971,   5.48754377],
#        [-13.20112068,  -3.7854973 ,  -2.42402968, ...,   2.81244742,
#           2.18634551,  -0.04771155],
#        ...,
#        [-17.07107394,  -0.10298544,   4.33763292, ...,  -1.42171131,
#          -0.47589105,   0.31502992],
#        [ -9.77502275,   4.07756062,   3.43127646, ...,  -0.50767361,
#          -2.11673205,   0.65339031],
#        [ 13.32258071,  -0.07680516,   5.40790662, ...,  -1.19887711,
#           5.14363975,   4.67255561]])

# %%
df=pd.DataFrame(x)
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    17.393711 -1.363605 -7.713914  2.313333  3.701270 -2.288522 -2.271915
# 1    18.995692 -3.168181 -1.066603  2.073015 -4.713477 -3.759412  2.187481
# 2   -13.201121 -3.785497 -2.424030 -4.759197  1.798192  0.814317 -1.289641
# 3    24.096562 -3.494336 -1.876237 -1.194718 -1.657673  3.849622  2.096618
# 4    -7.966323 -5.951815 -3.582806 -3.209036 -1.015917 -4.583518  3.458903
# ..         ...       ...       ...       ...       ...       ...       ...
# 535   8.253302  2.326278  4.560755 -3.127041 -1.495651 -2.647934 -1.507581
# 536 -17.293898 -0.244025  0.017400  0.305402 -1.684514  3.032410 -1.368020
# 537 -17.071074 -0.102985  4.337633 -0.085058 -2.104214  5.731113  3.377052
# 538  -9.775023  4.077561  3.431276 -0.373502 -5.473442  0.059796 -1.362806
# 539  13.322581 -0.076805  5.407907  2.545837 -0.191327 -1.240843  4.291619
#
#             7         8         9
# ...

# %% [markdown]
# # ensemble technique

# %%
x.shape
# Out:
# (540, 10)

# %%
y.shape
# Out:
# (540,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.46963533, -0.26158694, -1.96993667, ..., -0.14356354,
#          0.67257953,  0.82288066],
#        [ 1.60499038, -0.60776731, -0.27238326, ..., -0.0713233 ,
#         -1.59759285,  2.39135181],
#        [-1.11539354, -0.72619016, -0.61903527, ...,  1.16463466,
#          0.93790266, -0.02079165],
#        ...,
#        [-1.44237493, -0.01975619,  1.10772067, ..., -0.58873075,
#         -0.20414865,  0.13728316],
#        [-0.82591452,  0.78221807,  0.87626037, ..., -0.21022768,
#         -0.90803975,  0.28473324],
#        [ 1.12565598, -0.0147339 ,  1.38104124, ..., -0.49645509,
#          2.20652839,  2.03619776]])

# %%
import scipy
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.2)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state{i}, the training accuracy is: {r2_score(y_train,pred_train)}")
    print(f"At random state{i}, the testing accuracy is: {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state0, the training accuracy is: 0.9616641543191147
# At random state0, the testing accuracy is: 0.9808783247639449
#
#
# At random state1, the training accuracy is: 0.9612582776902878
# At random state1, the testing accuracy is: 0.985035997968778
#
#
# At random state2, the training accuracy is: 0.9629164748281737
# At random state2, the testing accuracy is: 0.9839427829369863
#
#
# At random state3, the training accuracy is: 0.9602205609749072
# At random state3, the testing accuracy is: 0.9866392008286592
#
#
# At random state4, the training accuracy is: 0.9631040652194441
# At random state4, the testing accuracy is: 0.9782290960412557
#
#
# At random state5, the training accuracy is: 0.9637709215212289
# At random state5, the testing accuracy is: 0.9764383402235426
#
#
# At random state6, the training accuracy is: 0.9596732109180545
# At random state6, the testing accuracy is: 0.9892248216319421
#
#
# At random state7, the training accuracy is: 0.9626774276461673
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=93,test_size=0.2)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9765185228587295

# %% [markdown]
# we get this r2_score because of the overhead, so we can do cross validation model

# %%
train_accuracy=r2_score(y_train,pred_train)
test_accuracy= r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold2 the cv score is 0.8933496391954816 and accuracy score for training is -0.98990983688577 and accuracy for testing is 0.9765185228587295
#
#
# At cross fold3 the cv score is 0.9584110349056861 and accuracy score for training is -0.98990983688577 and accuracy for testing is 0.9765185228587295
#
#
# At cross fold4 the cv score is 0.9492950778153401 and accuracy score for training is -0.98990983688577 and accuracy for testing is 0.9765185228587295
#
#
# At cross fold5 the cv score is 0.96274307504224 and accuracy score for training is -0.98990983688577 and accuracy for testing is 0.9765185228587295
#
#
# At cross fold6 the cv score is 0.9609375101077561 and accuracy score for training is -0.98990983688577 and accuracy for testing is 0.9765185228587295
#
#
# At cross fold7 the cv score is 0.9587699895671705 and accuracy score for training is -0.98990983688577 and accuracy for testing is 0.9765185228587295
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title('linear regression',fontsize=18)
plt.show()

# %% [markdown]
# observation - best fit line is covering the datapoints

# %%
print('mean abs',mean_absolute_error(y_test,pred_test))
# Out:
# mean abs 0.0579288673869084

# %%
print('sqr mean',mean_squared_error(y_test,pred_test))
# Out:
# sqr mean 0.007886824626927047

# %% [markdown]
# # Regularisation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters= {'alpha':[0.0001,0.001,0.01,.1,1,10],
            'random_state':list(range(0,10))}

ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
#final_model_training

# %%
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls_score=ls.score(x_train,y_train)
pred_ls= ls.predict(x_test)
ls_score*100
# Out:
# 96.33914986702811

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 96.30692730601258

# %%
difference =96.33248045154804-96.31850174665885

# %%
difference
# Out:
# 0.013978704889183291

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters= {'criterion':['mse','mae'],
            'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="auto")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_de =rf.predict(x_test)
rfs= r2_score(y_test,pred_de)
print("r2_score:",rfs*100)
# Out:
# r2_score: 97.45722030812547

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm  import SVR 

parameters= {'kernel':['poly','rbf','linear'],
            'C':[1,10]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
svr=SVR(kernel='linear',C=10)
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_svr = svr.predict(x_test)
svr_r2 = r2_score(y_test,pred_svr)
print("r2_score",svr_r2*100)
# Out:
# r2_score 97.644169961623

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr =KNeighborsRegressor()

# %%
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
knrpred = knr.predict(x_test)
knr_r2 = r2_score(y_test,knrpred)
print("r2_Score",knr_r2*100)
# Out:
# r2_Score 84.26240574256254

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV
parameters= {'criterion':['mse','mae'],
            'max_features':['auto','log2','sqrt']}

clf1=GridSearchCV(dtr,parameters)
clf1.fit(x_train,y_train)
print(clf1.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
dtr=DecisionTreeRegressor(criterion="mse",max_features="auto")
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
pred_dec =dtr.predict(x_test)
rfs= r2_score(y_test,pred_dec)
print("r2_score:",rfs*100)
# Out:
# r2_score: 96.31357069303344

# %% [markdown]
# svr was the best

# %%
svrscore = cross_val_score(svr,x,y,cv=5)
svr=svrscore.mean()
print('cross_val:',svr*100)
# Out:
# cross_val: 96.4681955399856

# %% [markdown]
# svc is the best model

# %%
import pickle

# %%
filename='student_grades.pkl'
pickle.dump(svr,open(filename,'wb'))

# %% [markdown]
# # conclusion

# %%
import numpy as np

# %%
a= np.array(y_test)
predicted= np.array(lr.predict(x_test))
df_data= pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
df_data
# Out:
#      original  predicted
# 0       3.648   3.687910
# 1       2.042   2.081909
# 2       2.311   2.309065
# 3       1.805   1.752011
# 4       3.621   3.627990
# ..        ...        ...
# 103     3.334   3.232025
# 104     3.026   2.928683
# 105     3.387   3.350715
# 106     2.300   2.319116
# 107     2.484   2.506813
#
# [108 rows x 2 columns]
